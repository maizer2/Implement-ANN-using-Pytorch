# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.use("seaborn-whitegrid")

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

# %%
plt.plot(x, y, 'o', color='black')

# %%
# string{0}.format()

a = 1
b = 2

# print("a is {0}".format(a))
print("a is {0}\nb is {1}".format(a, b))
# Out:
# a is 1
# b is 2

# %%
rng = np.random.RandomState(0)
# print(rng.rand(5))
# print(rng.rand(5))

for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    # print(marker)
    plt.plot(rng.rand(5), rng.rand(5), marker, label="marker='{0}'".format(marker))
    # plt.plot(rng.rand(5), rng.rand(5), marker, label=marker)
    # print("marker='{0}'".format(marker))

plt.legend(numpoints=1)
plt.xlim(0, 1.5)
# Out:
# (0.0, 1.5)

# %%
row = 3
column = 1

plt.subplot(row, column, 1)
plt.plot(x, y, '-ok')

plt.subplot(row, column, 2)
plt.plot(x, y, '-or')

# %%
plt.plot(x, y, '-p', color='gray',
         markersize=15, linewidth=4,
         markerfacecolor='white',
         markeredgecolor='gray',
         markeredgewidth=2)
plt.ylim(-1.2, 1.2)
# Out:
# (-1.2, 1.2)

# %%
plt.scatter(x, y, marker='o')

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

# %%
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
            cmap='viridis')

plt.colorbar()
# Out:
# /var/folders/wz/d1brbrm50_5_xr7k83_vwgsh0000gn/T/ipykernel_1486/4161310598.py:4: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %%
from sklearn.datasets import  load_iris

iris = load_iris()
features = iris.data.T

plt.scatter(feature[0], feature[1], alpha=0.2,
            s=100*features[3], c=iris.target, cmap='viridis')

plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
